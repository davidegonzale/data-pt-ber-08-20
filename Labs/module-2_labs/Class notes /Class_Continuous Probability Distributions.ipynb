# %% [markdown]
# # Continuos Distributions

# %% [markdown]
# ### Continuos Uniform Distribution

# %%
import numpy as np
import pandas as pd 
import scipy.stats
import matplotlib.pyplot as plt 
from scipy.stats import uniform

# %%
cuni = uniform()
test= cuni.rvs(size=10)
print(test)
print(test[0])
# Out:
# [0.74357639 0.65478785 0.19321407 0.72515263 0.54182778 0.2163722
#  0.97176335 0.72777095 0.18702271 0.10987999]
# 0.7435763864720012

# %%
x = cuni.rvs(size=1000)
plt.hist(x, bins=100)
# Out:
# (array([ 8.,  6.,  6.,  9., 12., 16., 10., 12., 12.,  9., 11.,  7., 11.,
#          7.,  6., 13., 14.,  3., 10., 15., 11., 13.,  8., 11.,  8., 11.,
#          6., 13., 14.,  9., 12., 11.,  9.,  5.,  8., 10., 16.,  4., 13.,
#          9., 14., 10., 11., 10.,  6.,  3., 10., 12.,  7., 17.,  8., 10.,
#          9.,  8., 14.,  4., 11., 12.,  9.,  8.,  9.,  8., 12., 10., 10.,
#         10., 11., 10., 11., 15., 12.,  9., 11.,  7., 14., 17.,  7., 13.,
#         16., 12.,  7., 12.,  7.,  9.,  8., 14., 16.,  5., 11.,  6.,  7.,
#         11., 10.,  6.,  9.,  3., 11., 14.,  8., 11.]),
#  array([0.00110293, 0.01108455, 0.02106618, 0.0310478 , 0.04102942,
#         0.05101105, 0.06099267, 0.0709743 , 0.08095592, 0.09093755,
#         0.10091917, 0.1109008 , 0.12088242, 0.13086405, 0.14084567,
#         0.1508273 , 0.16080892, 0.17079055, 0.18077217, 0.1907538 ,
#         0.20073542, 0.21071705, 0.22069867, 0.2306803 , 0.24066192,
#         0.25064355, 0.26062517, 0.2706068 , 0.28058842, 0.29057005,
#         0.30055167, 0.3105333 , 0.32051492, 0.33049655, 0.34047817,
#         0.35045979, 0.36044142, 0.37042304, 0.38040467, 0.39038629,
#         0.40036792, 0.41034954, 0.42033117, 0.43031279, 0.44029442,
#         0.45027604, 0.46025767, 0.47023929, 0.48022092, 0.49020254,
#         0.50018417, 0.51016579, 0.52014742, 0.53012904, 0.54011067,
#         0.55009229, 0.56007392, 0.57005554, 0.58003717, 0.59001879,
#         0.60000042, 0.60998204, 0.61996367, 0.62994529, 0.63992692,
#         0.64990854, 0.65989016, 0.66987179, 0.67985341, 0.68983504,
#         0.69981666, 0.70979829, 0.71977991, 0.72976154, 0.73974316,
#         0.74972479, 0.75970641, 0.76968804, 0.77966966, 0.78965129,
#         0.79963291, 0.80961454, 0.81959616, 0.82957779, 0.83955941,
#         0.84954104, 0.85952266, 0.86950429, 0.87948591, 0.88946754,
#         0.89944916, 0.90943079, 0.91941241, 0.92939404, 0.93937566,
#         0.94935729, 0.95933891, 0.96932053, 0.97930216, 0.98928378,
#         0.99926541]),
#  <BarContainer object of 100 artists>)

# %%
#np.linspace
numrange = np.linspace(-0.1, 1.1, 100)
plt.plot(numrange, cuni.pdf(numrange))

# %%
numrange2 = np.linspace(-0.1, 1.1, 100)
plt.plot(numrange2, cuni.cdf(numrange2))

# %%
cuni = uniform(0, 10)
numrange = np.linspace(-1, 11, 100)
plt.plot(numrange, cuni.pdf(numrange))

# %%
from scipy.stats import norm

# %%
normal = norm(0,1)
numerange = np.linspace (-5,5, 100)
plt.plot(numerange, normal.pdf(numerange))

# %%
plt.plot(numerange, normal.cdf(numerange))

# %%
x = normal.rvs(size=10000)

plt.hist(x, bins=100)
plt.show()
