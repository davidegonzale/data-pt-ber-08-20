# %% [markdown]
# ##  Imports

# %%
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Challenge 1:
#
# Get the Bitcoin market value vs USD for last 30 days. For your results, you would like to deliver them both as a DataFrame and then create an appropriate plot.
#
# Hint: start by creating a base_url for the Coingecko API, and then adding the parameters you want by looking at the documentation, which you can find here: https://www.coingecko.com/api/documentations/v3#
#
# Specifically in this example, we are looking at: https://www.coingecko.com/api/documentations/v3#/coins/get_coins__id__market_chart
#
# You want a coin (Bitcoin), vs USD, timeframe of 30 days.
#
# For creating the DataFrame, you can print out all of the keys of your resulting json file, to see which ones you would like to extract as columns! The timestamp for these dataseries is in milliseconds - you can convert it to a convenient format using pd.to_datetime (look into how you can specify the unit here!)

# %%
# Your code here:
base = 'https://api.coingecko.com/api/v3/'
url = base + 'coins/bitcoin/market_chart'
param_dict = {'id':'bitcoin', 'vs_currency':'usd', 'days':30}

response = requests.get(url, params=param_dict)
results = response.json()

print(results.keys())

# now create a dataframe and a plot!
df = pd.DataFrame(results['prices'])
df.columns = ['Time', 'Price']
df
# Out:
# dict_keys(['prices', 'market_caps', 'total_volumes'])
#               Time         Price
# 0    1599822440384  10292.184571
# 1    1599825687984  10263.133571
# 2    1599829486574  10292.982391
# 3    1599832849593  10285.150815
# 4    1599836774857  10301.670587
# ..             ...           ...
# 716  1602400072449  11361.029448
# 717  1602403781452  11354.064175
# 718  1602406928291  11346.824204
# 719  1602411013575  11345.434977
# 720  1602412968000  11362.202369
#
# [721 rows x 2 columns]

# %%
df['Time'] = pd.to_datetime(df['Time'], unit = "ms")

# %%
plt.plot(df['Time'], df['Price'])

# %% [markdown]
# ### Challenge 2:
#
# Get the Litecoin market value vs USD for last 30 days. For your results, you would like to deliver them both as a DataFrame and then create an appropriate plot.

# %%
base = 'https://api.coingecko.com/api/v3/'
url = base + 'coins/litecoin/market_chart'
param_dict = {'id':'Litecoin', 'vs_currency':'usd', 'days':30}

response = requests.get(url, params=param_dict)
results = response.json()

print(results.keys())

df2 = pd.DataFrame(results['prices'])
df2.columns = ['Time', 'Price']
df2
# Out:
# dict_keys(['prices', 'market_caps', 'total_volumes'])
#               Time      Price
# 0    1599822392788  48.414876
# 1    1599825833107  48.219593
# 2    1599829400107  48.526107
# 3    1599833088090  48.473537
# 4    1599836723120  48.745431
# ..             ...        ...
# 717  1602403872655  49.676800
# 718  1602407513698  49.583930
# 719  1602411119592  49.560080
# 720  1602414301870  50.553368
# 721  1602414350000  50.634956
#
# [722 rows x 2 columns]

# %%
df2['Time'] = pd.to_datetime(df2['Time'], unit = "ms")
plt.plot(df2['Time'], df2['Price'])

# %% [markdown]
# ### Challenge 3:
#
# Get historical data for Bitcoin on January 1st, 2020. As a result, you would like to have a Dataframe which contains all of the currencies against which the price is expressed in one column, and the current price (at that date) in a second column.
#
# Hint: you might receive an error message saying "If using all scalar values, you must pass an index". Google it! :)

# %%
base = 'https://api.coingecko.com/api/v3/'
url = base + 'coins/bitcoin/history'
param_dict = {'id':'bitcoin', 'date': '01-01-2020'}

response = requests.get(url, params=param_dict)
results = response.json()

test = results['market_data']['current_price']

df = pd.Series(test).to_frame().reset_index()

df
# Out:
#    index             0
# 0    aed  2.642924e+04
# 1    ars  4.305630e+05
# 2    aud  1.025681e+04
# 3    bch  3.513946e+01
# 4    bdt  6.106991e+05
# 5    bhd  2.712904e+03
# 6    bmd  7.195154e+03
# 7    bnb  5.245665e+02
# 8    brl  2.892430e+04
# 9    btc  1.000000e+00
# 10   cad  9.358377e+03
# 11   chf  6.960592e+03
# 12   clp  5.320109e+06
# 13   cny  5.010202e+04
# 14   czk  1.630990e+05
# 15   dkk  4.794275e+04
# 16   eos  2.781881e+03
# 17   eth  5.568502e+01
# 18   eur  6.412846e+03
# 19   gbp  5.425866e+03
# 20   hkd  5.603982e+04
# 21   huf  2.124570e+06
# 22   idr  9.989032e+07
# 23   ils  2.485350e+04
# 24   inr  5.130217e+05
# 25   jpy  7.820050e+05
# 26   krw  8.308532e+06
# 27   kwd  2.181549e+03
# 28   lkr  1.304736e+06
# 29   ltc  1.740887e+02
# 30   mmk  1.061772e+07
# 31   mxn  1.362215e+05
# 32   myr  2.943178e+04
# 33   nok  6.345838e+04
# 34   nzd  1.070709e+04
# 35   php  3.641519e+05
# 36   pkr  1.114376e+06
# 37   pln  2.738296e+04
# 38   rub  4.464246e+05
# 39   sar  2.698977e+04
# 40   sek  6.740348e+04
# 41   sgd  9.704824e+03
# 42   thb  2.136591e+05
# 43   try  4.280253e+04
# 44   twd  2.152286e+05
# 45   uah  1.704864e+05
# 46   usd  7.195154e+03
# 47   vef  1.787907e+09
# 48   vnd  1.667811e+08
# 49   xag  4.029206e+02
# 50   xau  4.742254e+00
# 51   xdr  5.197441e+03
# 52   xlm  1.597723e+05
# 53   xrp  3.727995e+04
# 54   zar  1.008106e+05
# 55  link  4.081727e+03

# %% [markdown]
# ### Challenge 3:
#
# Get the ids of all of the coins listed on Coingecko. Extract the bottom ten IDs in a Dataframe.

# %%
base = 'https://api.coingecko.com/api/v3/'
url = base + 'coins/list'

response = requests.get(url)
results = response.json()

top10 = [result['id'] for result in results][-10:]
top10
# Out:
# ['zulu-republic-token',
#  'zumcoin',
#  'zum-token',
#  'zumy',
#  'zvchain',
#  'zxth',
#  'zynecoin',
#  'zyro',
#  'zyx',
#  'zzz-finance']

# %% [markdown]
# ### Bonus Challenge:
#
# Write a loop that goes through the 10 coins you retrieved in challenge 3, and for each of them collects the market values against USD for the last 30 days. Then create a dataframe which has three columns: 'time', 'price' and 'coin' and combines the data of all these ten coins.
#
# If you're ambitious: create a plot with 10 subplots for all of the series!

# %%
# Your code here:
df_all = pd.DataFrame()

for i in top10:
    url = base + 'coins/' + i + '/market_chart'
    param_dict = {'id': i, 'vs_currency':'usd', 'days':30}
    response = requests.get(url, params = param_dict)
    results = response.json()
    df = pd.DataFrame(results['prices'], columns=['time', 'price'])
    df['coin'] = i
    df_all = pd.concat([df_all, df])
df_all
# Out:
#               time       price                 coin
# 0    1600413417475    0.001046  zulu-republic-token
# 1    1600416921327    0.001047  zulu-republic-token
# 2    1600420658004    0.001048  zulu-republic-token
# 3    1600424229370    0.001052  zulu-republic-token
# 4    1600849043844    0.000417  zulu-republic-token
# ..             ...         ...                  ...
# 716  1602401204256  132.787232          zzz-finance
# 717  1602404836970  133.321182          zzz-finance
# 718  1602408483883  132.428117          zzz-finance
# 719  1602412096722  132.075874          zzz-finance
# 720  1602413267000  132.686944          zzz-finance
#
# [4602 rows x 3 columns]

# %%
fig = plt.figure()

for num in range(10):
    i = top10[num]
    ax = fig.add_subplot(5,2,num+1)
    subdf = df_all[df_all['coin'] == i]
    ax.plot(subdf['time'], subdf['price'])
    ax.set_title(i)
plt.show()
